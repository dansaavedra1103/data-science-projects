# %% [markdown]
# <a href="https://colab.research.google.com/github/dansaavedra1103/data-science-projects/blob/main/An%C3%A1lisis_de_sentimientos_corpus_de_noticias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
noticias = ['Las elecciones regionales del 29 de octubre le medirán el pulso a la reincorporación política de los firmantes del Acuerdo de Paz. ¿Por qué serán decisivas para la continuidad del Partido Comunes?',
 'Conozca cuáles son las propuestas y posturas de quienes aspiran a la Gobernación de Antioquia en torno a los temas más claves de Urabá. Debate virtual de la serie “Colombia Afro Decide”.',
 'Este miércoles 20, de 5:30 a 6:30 pm, por YouTube, Facebook y nuestro portal web, y por 10 canales locales, el quinto de nueve debates virtuales de “Colombia Afro Decide”.',
 'Las propuestas de los candidatos en Bogotá y Cundinamarca parecen cada vez más ligadas al rol de la Región Metropolitana. Conclusiones del debate de candidatos a la Alcaldía de Bogotá y a la Gobernación de Cundinamarca organizado por El Espectador, Blu Radio, Caracol Televisión y la Universidad EAN.',
 'Durante una hora, todos los candidatos a la gobernación de Antioquia expusieron sus ideas en el auditorio de la Universidad Eafit. En tres bloques temáticos se trataron temas de medio ambiente, seguridad, educación, entre otros.',
 'Este miércoles 13, de 5:30 a 6:30 pm por YouTube, Facebook y portal web, el cuarto de nueve debates virtuales de “Colombia Afro Decide”.',
 'A 10 días de los comicios locales, muchos capitalinos siguen indecisos y, para resolver sus dudas, El Espectador les recopila las propuestas y las opiniones de los candidatos a la Alcaldía de Bogotá. Si sigue teniendo dudas, no sobra que pase y haga nuestro Match Electoral.',
 'Horacio José Serpa, candidato a la Alcaldía de Bucaramanga e hijo del exgobernador Horacio Serpa, habla sobre cómo su apellido influencia sus aspiraciones políticas de cara a las regionales del 29 de octubre.',
 'El exdirector de la Policía fue uno de los últimos en inscribirse como candidato a la Alcaldía. En entrevista con El Espectador habla de su salto a la política, sus críticas al gobierno Petro y sus propuestas.',
 'Vote informado. Hablamos con cada uno de los candidatos a la Alcaldía de Bogotá. En esta ocasión, el exdirector del DANE revela sus visiones de ciudad y sus propuestas para enfrentar los problemas de seguridad, movilidad y hacinamiento, entre otros.'
 'Así llegan los ex-FARC a elecciones: 144 candidatos y un futuro político por definir',
 'Candidatos a la Gobernación de Antioquia debaten en El Espectador',
 '¿Qué proponen los candidatos de Antioquia para Urabá? El debate en El Espectador',
 'Movilidad, el reto común que deberán resolver próximos mandatarios de Bogotá y Cundinamarca',
 '“Elefantes blancos”: así fue el debate de candidatos a la Gobernación de Antioquia',
 '¿Qué proponen los candidatos a la Alcaldía de Turbo? Siga el debate en El Espectador',
 '¿Indeciso para votar? conozca qué piensan los candidatos a la Alcaldía de Bogotá',
 '“Uno no escoge dónde nace, pero sí dónde quiere trabajar”: Horacio José Serpa',
 '“No soy ni de izquierda ni de derecha, mi propuesta es por la seguridad de Bogotá”: Jorge Luis Vargas',
 '“Debemos montarnos en la doctrina policial para resolver la inseguridad”: Juan Daniel Oviedo',
 'Los cargos que se elegirán son regionales y locales.',
 'Molano afirmó que su campaña ha recibido ataques verbales, físicos y sabotajes.',
 'Los primeros municipios a los que llegó ese material fueron Cubará (Boyacá), Belén (Nariño), Carmen del Darién (Chocó), Dibulla (La Guajira) y Arauquita (Arauca).',
 'El candidato a la Alcaldía de Cali contesta la petición radicada por el representante Alejandro Ocampo, del Pacto Histórico.',
 'El próximo 29 de octubre se llevarán a cabo las elecciones regionales en Colombia.','“Gracias, pero no”: la tajante respuesta de Eder a Andrés Escobar que, extrañamente, salió a respaldar su candidatura a la Alcaldía de Cali',
 'Candidatos a la Alcaldía de Bogotá rechazan la reunión que quiere Petro para revisar el metro: “Vamos a defender ese proyecto”',
 'Elecciones 2023: ¿cuántos tarjetones se pueden pedir el día de las votaciones?',
 'Diego Molano solicita medidas cautelares ante la CIDH por falta de garantías en la campaña a la Alcaldía de Bogotá',
 'Elecciones territoriales 2023: El 25 % de los kits electorales ya han sido distribuidos en el país',
 '“Miren a los niveles que está llegando la politiquería”: Alejandro Eder responde a la demanda para revocar su candidatura',
 'Elecciones 2023: ¿se puede votar con otro documento que no sea la cédula?','El candidato a la Gobernación de ese departamento aseguró que sería una medida positiva que ayudaría a reducir el consumo de sustancias psicoactivas.',
 'El 29 de octubre se harán las elecciones regionales en Colombia.',
 'El exdirector del Dane habló con SEMANA y entregó detalles del encuentro que se registró este martes en Bogotá. También se ha encontrado con otros directores de partidos políticos.',
 '',
 'Los resultados fueron presentados por una encuesta Invamer realizada para revisar la intención de voto en ese departamento.',
 '“Si no se paga, los proyectos no salen”, dijo el empresario Luis Alfredo Quintero, quien hizo una delicada denuncia a pocos días de elecciones.',
 'Todas las campañas políticas deben finalizar los actos públicos. El 29 de octubre se harán las elecciones en Colombia.',
 'Así lo denunció Sandra Forero, expresidenta de Camacol y hoy candidata al Concejo de Bogotá.',
 'Jenny Astaiza presentó una denuncia en contra de la exalta funcionaria del Gobierno porque, dice, le habría negado la posibilidad de trabajar por una condición física que presenta por un accidente automovilístico que sufrió.',
 'El candidato a la Gobernación de ese departamento aseguró que sería una medida positiva que ayudaría a reducir el consumo de sustancias psicoactivas.',
 'El 29 de octubre se harán las elecciones regionales en Colombia.',
 'En las últimas horas, el exmiembro del secretariado de las Farc dice que él y el sector que representa votarán por el candidato en las próximas elecciones.',
 'El actual aspirante a la Gobernación de Santander reveló detalles de su lucha contra el cáncer, una enfermedad que lo mantuvo durante 15 días en una Unidad de Cuidados Intensivos.',
  'Héctor Mantilla propone la creación de centros de desintoxicación estatales en Santander',
 'Mauricio Tobón arremete contra la alianza de Luis Pérez y Julián Bedoya: “Petro los juntó para robarse Antioquia”',
 'Confirmado: Juan Daniel Oviedo y Germán Vargas Lleras sí se reunieron esta semana en Bogotá: ¿de qué hablaron?',
 'Cambio Radical mantiene su respaldo en firme a la candidatura del general (r) Jorge Luis Vargas en Bogotá',
 'Alejandro Char encabeza intención de voto a la Alcaldía de Barranquilla; Eduardo Verano se impone por la Gobernación del Atlántico, según Invamer',
 'Empresario salpica a varios políticos en Norte de Santander y la Procuraduría pide a la Fiscalía que se investigue de inmediato',
 'Juan Carlos Upegui y Daniel Quintero empezaron el cierre de campaña con una maratón en Medellín',
 'En pleno año electoral, las alcaldías locales en Bogotá aumentaron en un 88% los contratos firmados sin proceso de selección',
 'Cielo Rusinque, exdirectora del DPS, dice que no conocía condición de discapacidad de una mujer que iba a contratar; la persona reclama que lo aclaró desde un comienzo',
 'Héctor Mantilla propone la creación de centros de desintoxicación estatales en Santander',
 'Mauricio Tobón arremete contra la alianza de Luis Pérez y Julián Bedoya: “Petro los juntó para robarse Antioquia”',
 'Pastor Alape, excomandante de las sangrientas Farc, respaldó a Luis Pérez para la Gobernación de Antioquia. El grupo criminal fue cruel en ese departamento',
 'Rodolfo Hernández habla crudamente del dolor del cáncer, de sus días en una UCI, del tubo que padeció en su garganta y de su larga cirugía para extirpar un tumor. “Eso no se lo deseo a nadie”']

# %%
# !pip install transformers>=4.0
# !pip install sentencepiece

import tensorflow as tf
assert tf.__version__ >= "2.0"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.3 MB/s eta 0:00:00
# ...

# %%
from transformers import pipeline
import pandas as pd
data = pd.DataFrame(list(noticias))

model_path = "cardiffnlp/twitter-xlm-roberta-base-sentiment"
sentiment_task = pipeline("sentiment-analysis", model=model_path, tokenizer=model_path)

def procesar_texto(texto):
    resultados = sentiment_task(texto)
    return resultados

data['sentimiento'] = data[data.columns[0]].apply(procesar_texto)

# %%
import matplotlib.pyplot as plt
import pandas as pd
from collections import defaultdict

label_votes = defaultdict(float)

# Sumar los valores de 'score' para cada etiqueta
for sublist in noticias_arregladas:
    for item in sublist:
        label = item['label']
        score = item['score']
        label_votes[label] += score

# Convertir el diccionario a un DataFrame para usarlo en el trazado
df_agrupado = pd.DataFrame(list(label_votes.items()), columns=['label', 'VOTES'])
bar_colors = ['red', 'orange', 'yellow']
# Crear el gráfico de barras
df_agrupado.plot(x='label', y='VOTES', kind='bar', stacked=True, figsize=(10, 6),color=bar_colors)
plt.xlabel('Etiqueta')
plt.ylabel('Total de Votos')
plt.title('Gráfico de Barras de Votos por Etiqueta')
plt.show()

# %%
data
# Out:
#                                                     0  \
# 0   Las elecciones regionales del 29 de octubre le...
# 1   Conozca cuáles son las propuestas y posturas d...
# 2   Este miércoles 20, de 5:30 a 6:30 pm, por YouT...
# 3   Las propuestas de los candidatos en Bogotá y C...
# 4   Durante una hora, todos los candidatos a la go...
# ..                                                ...
# 75  Cielo Rusinque, exdirectora del DPS, dice que ...
# 76  Héctor Mantilla propone la creación de centros...
# 77  Mauricio Tobón arremete contra la alianza de L...
# 78  Pastor Alape, excomandante de las sangrientas ...
# 79  Rodolfo Hernández habla crudamente del dolor d...
#
#                                           sentimiento
# 0   [{'label': 'neutral', 'score': 0.6281610131263...
# 1   [{'label': 'neutral', 'score': 0.8813631534576...
# 2   [{'label': 'neutral', 'score': 0.8980391621589...
# 3   [{'label': 'neutral', 'score': 0.6794900894165...
# ...
